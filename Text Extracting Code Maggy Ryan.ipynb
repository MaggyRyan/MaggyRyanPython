# %% [raw]
# Name: Maggy Ryan
# Student ID: 998 037 677

# %% [markdown]
# Questions:
# 1: What is the most common set of prerequisite courses a freshman would need to take at UC Davis by college?
# 2: What would be the best six courses to take at uc davis as a freshman who does not know what they want to study?

# %% [markdown]
# We'll start with the college of biological sciences.

# %% [markdown]
# The first thing to do is to import all of the packages that we need to use for the code. I did this at the beginning to keep them organized so that I could reference what I already had instead of accidentally importing one package multiple times.

# %%
# We'll start by importing all the packages we need.
# BeautifulSoup is used for webscraping
# urllib.request is used to open the URLs
# requests, requests_cache, and re are used to cache the web results so we don't have to retreive from the server each time we run the program.

from bs4 import BeautifulSoup
import urllib.request as urllib2

import requests
import requests_cache
import re
requests_cache.install_cache('demo_cache')

# %% [markdown]
# The next step is to define where exactly in the webpage the lower-division pre-requisite courses are located. This was tricky because the majors were in slightly different formats, but I was eventually able to come up with a general function to properly extract all the necessary data. A list of UC Davis classes will be returned at the end for the major whose URL was used for the function.

# %%
"""
This function takes a URL from a UC Davis major page and returns the list of rerequisite couress for that major.

Inputs:
    majorUrl: This is the URL that we will be text scraping from
    
Outputs:
    classList: This is the list of lower-division courses required for any given major.

"""

def getLowerDivRequirements(majorUrl):
    page = requests.get(majorUrl)

# This extracts the HTML from the page the running it through beautiful soup to parse
    soup = BeautifulSoup(page.text,'html.parser')
    if 'registrar' in majorUrl:       
        page = requests.get(soup.a.get('href'))
        soup = BeautifulSoup(page.text,'html.parser')

# This defines the start and stop locations for extracting text. We're only interested in the lower div courses
# Two start strings and two stop strings were used as different colleges phrased the start and stop areas slightly differently
    startString1 = 'Preparatory Subject Matter'
    startString2 = 'Lower Division Required Courses'
    stopString1 = 'Depth Subject Matter'
    stopString2 = 'Upper Division Required Courses'
    stopChar = '('
    prepMatter = False
    i = 0

# "tr" and "td" are html tags containing the text that we need.    
    classList = []
    for row in soup.findAll('tr'):
        
        data = row.findAll('td')
        if len(data) < 0:
            print(data[0].text)
            if len(data) < 2 and prepMatter or (data[0].text == stopString1 or data[0].text == stopString2):
                prepMatter = False

# This extracts the prerequisite courses                
        if prepMatter:
            classStrings = data[0].text.split()
            if len(classStrings) < 2 or len(classStrings[0]) < 2:
                continue
            classNumbers = False
            className = ''
            
# This searches for the end of the prerequisite courses            
            if classStrings[0] == 'Depth' or (classStrings[0] == 'Total' and classStrings[1] == 'Depth') or (classStrings[0] == 'Upper' and classStrings[1] == 'Division'):
                break

          
            for string in classStrings:

# Here, we're looking for the correct strings that represent courses.            
                if string == 'Students' or string == 'Prerequisites' or 'string' == 'Select' or string == 'Choose':
                    break

# If two courses are separated by an "and" we skip it and go to the next number.
                if classNumbers == True and string == 'and':
                    continue
# This removes ampersands                    
                if len(string) > 1 and string[0] == '&':
                    string = string.replace('&','')

# If an "either" appears, we reset the class name and then skip. Take either CHE 2A or BIS 2A both CHE2A and BIS 2A would be included.         
                if string == 'either' or ':' in string or '(' in string:
                    className = ''
                    continue

# If we come arcross an "or" then we skip it                
                if string == 'or' or (string == '&' and classNumbers == True):
                    continue

# This finds the start of new classes if we find an uppercase character immediately after a number            
                if classNumbers == True and string[0].isupper() == True:
                    className = ''
                    classNumbers = False

# If there is a string that is not a number or if there is a number followed by an uppercase letter, then we add it to the name of the course subject area.         
                if (string[0].isdigit() == False) or (classNumbers == True and classNumbers == string[0].isupper()):
                    className += string + ' '

# This puts the course letters and numbers in the right format taking into accoutn the initial different in how they are listed (e.g. commas, semicolons, dashes, etc..
                else:
                    classNumbers = True                   
                    classNum = ''.join([i for i in string if i.isdigit()])                                       
                    if len(classNum) > 1 and '-' in string: 
                        
                        if classNum[0] == classNum[1]:
                            classSubtitleList = string.split('-')
                            for sub in classSubtitleList:
                                sub = sub.replace(',','')
                                sub = sub.replace(';','')
                                classList.append(className + sub)
                        elif len(classNum) > 3:
                            if classNum[0] == classNum[2]:
                                classSubtitleList = string.split('-')
                                for sub in classSubtitleList:
                                    sub = sub.replace(',','')
                                    sub = sub.replace(';','')
                                    classList.append(className + sub)
                    else:
                        classLetter = ''.join([i for i in string if (not i.isdigit() and i != ',' and i != ';')])
                        classLetters = []
                        

                        classLetters = classLetter.split('&')
                            
                        if int(classNum) > 99:
                            continue
                        for letter in classLetters:
                            if len(className) > 1:
                                classList.append(className + classNum + letter)
        if data and (startString1 == data[0].text or startString2 == data[0].text):
            prepMatter = True
    print(classList)
    return classList

# %% [markdown]
# The next step is to start extracting the list of major links. I took all of the links from the same URL. I created an empty list for each college that was then populated with a list of all the majors from that undergraduate college at UC Davis.

# %%
# This goes to the website with links to all of the majors.
page = requests.get('https://www.ucdavis.edu/majors/college')
soup = BeautifulSoup(page.text,'html.parser')

# Initializing lists that will contain all the college major links
collegeCount = 0
prevStartChar = 'Z'
agList = []
bioList = []
engList = []
lsList = []

# This goes through everything within the tag 'a'
for row in soup.findAll('a'):

    # If there is a link we follow it to the webpage
    if row.get('href'):

        # If the link contains a link to a major we follow it
        if '/majors/' in row.get('href'):
            if row.text[0] < prevStartChar:
                collegeCount = collegeCount + 1

            # Below, we loop though each of the undergraduate colleges to extract the link to each major page in that college
            if row.text[0] == 'A' or (collegeCount > 4 and collegeCount < 9):
                if collegeCount == 5:
                    agList.append((row.text,'https://www.ucdavis.edu' + row.get('href')))
                    
                elif collegeCount == 6:
                    bioList.append((row.text,'https://www.ucdavis.edu' + row.get('href')))
                    
                elif collegeCount == 7:
                    engList.append((row.text,'https://www.ucdavis.edu' + row.get('href')))
                    
                elif collegeCount == 8:
                    lsList.append((row.text,'https://www.ucdavis.edu' + row.get('href')))

                prevStartChar = row.text[0]

# %% [markdown]
# The next step was to feed in the requirements. I used a for loop that iterated through the list and ran each URL through the function automatically instead of copying and pasting by hand which is both less efficient and introduces the possibility of human error. The major prerequieites were automatically sorted by undergraduate college. The last set of obtaining my data was to export each college's prerequisites to a csv. I did this so that any website outages would not effect my ability to complete my project. I also plan on providing these requirements to other students if they want to use this data for any further analysis.

# %%
import csv

"""
This function lists all of the major requirements for each major in a given undergraduate UC Davis college.

Inputs:
    majorList: The list of URL links for each major in an undergraduate UC Davis college. Function defined above.
    csvTitle: The name of the csv that the output will be saved.
    
Outputs:
    requirementsList: A list of all of the requirements sorted by major within college along with their lower-division prerequisite courses.

"""
def getAllRequirements(majorList,csvTitle):

    # Creating an empty list that will be filled with the requirements
    requirementsList = []

    # Looping through each major in the given list and extracting the prerequisite information
    for major in majorList:
        page = requests.get(major[1])
        soup = BeautifulSoup(page.text,'html.parser')


        for row in soup.findAll('a'):
            if row.text:
                if row.text == 'Detailed Major Requirements':
                    print(major[0])
                    print(row.get('href'))
                    requirementsList.append(getLowerDivRequirements(row.get('href')))
                    print('------------------')

    # This saves the list to a csv and exports it in the same directory                
    import csv                
    with open(csvTitle,'w') as resultFile:
        wr = csv.writer(resultFile, dialect='excel')
        wr.writerows(requirementsList)
    
    return requirementsList

# Putting each of the colleges through the function defined above
print("Lower-division prerequisite list for the College of Letters and Science:")
getAllRequirements(lsList,'lsreqs.csv')

print("Lower-division prerequisite list for the Agriculture and Environmental Sciences:")
getAllRequirements(agList,'agreqs.csv')

print("Lower-division prerequisite list for the College of Engineering:")
getAllRequirements(engList,'engreqs.csv')

print("Lower-division prerequisite list for the College of Biological Sciences:")
getAllRequirements(bioList,'bioreqs.csv')
# Out:
# Lower-division prerequisite list for the College of Letters and Science:
# African American and African Studies Major
# http://catalog.ucdavis.edu/programs/AAS/AASreqt.html
# ['African American and African Studies 10', 'African American and African Studies 12', 'African American and African Studies 15', 'African American and African Studies 17', 'African American and African Studies 18', 'African American and African Studies 50', 'African American and African Studies 51', 'African American and African Studies 52', 'African American and African Studies 80', 'Anthropology 2', 'Economics 1A', 'Economics 1B', 'Geography 2', 'Sociology 1', 'Political Science 1', 'Political Science 2', 'Psychology 1', 'Chicana/o Studies 10', 'Native American Studies 1', 'Native American Studies 10', 'Women & Gender Studies 50', 'American Studies 10', 'Asian American Studies 1', 'Asian American Studies 2', 'History 15', 'History 17A', 'History 17B', 'African American and African Studies 16', 'African American and African Studies 51', 'African American and African Studies 54', 'Dramatic Art 41A', 'Dramatic Art 41B', 'Dramatic Art 44A', 'Dramatic Art 44B', 'Music 28']
# ------------------
# American Studies Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/AMS/AMSreqt.html
# ['American Studies 10', 'African American and African Studies 10', 'Asian American Studies 1', 'Chicana/o Studies 10', 'Native American Studies 1', 'Anthropology 2', 'Sociology 2', 'Women\x92s Studies 50', 'History 17A', 'History 17B', 'History 72A', 'History 72B', 'English 30A', 'English 30B', 'Film Studies 1']
# ------------------
# Anthropology Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ANT/ANTreqt.html
# ['Anthropology 1', 'Anthropology 2', 'Anthropology 3', 'Anthropology 15', 'Anthropology 23', 'Anthropology 24', 'Anthropology 25', 'Anthropology 28', 'Anthropology 50', 'Anthropology 54', 'Anthropology 13', 'Sociology 46B', 'Statistics 13', 'Statistics 32']
# ------------------
# Applied Mathematics Major
# http://registrar.ucdavis.edu/UCDWebCatalog/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Applied Physics Major
# http://registrar.ucdavis.edu/UCDWebCatalog/Programs/PHY/PHYreqt.html
# ['Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Physics 9HA', 'Physics 9HB', 'Physics 9HC', 'Physics 9HD', 'Physics 9HE', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B']
# ------------------
# Art History Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/AHI/AHIreqt.html
# ['Art History 1A', 'Art History 1B', 'Art History 1C', 'Art History 1D', 'Art History 1DV', 'Art History 1E', 'Art History 5', 'Art History 25', 'Any lower division Art Studio course except Art 10', 'Any lower division Art Studio course except Art 30']
# ------------------
# Art Studio Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ART/ARTreqt.html
# ['Art Studio 2', 'Art Studio 5', 'Art Studio 7', 'Art Studio 8', 'Art Studio 9', 'Art Studio 11', 'Art Studio 12', 'Art Studio 24', 'Art Studio 30', 'Art History 1A', 'Art History 1B', 'Art History 1C', 'Art History 1D', 'Art History 1DV', 'Art History 1E', 'Art History 5', 'Art History 10', 'Art History 25']
# ------------------
# Asian American Studies Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ASA/ASAreqt.html
# ['Asian American Studies 1', 'Asian American Studies 2', 'Asian American Studies 3', 'Asian American Studies 4', 'lower division courses of at least 4', 'lower division courses of at least units are acceptable except those numbered 92', 'lower division courses of at least units are acceptable except those numbered 97T', 'lower division courses of at least units are acceptable except those numbered 98', 'lower division courses of at least units are acceptable except those numbered 99)', 'Anthropology 13', 'Art History 5', 'Art Studio 10', 'Art Studio 30', 'Chicana/o Studies 23', 'English 42', 'Native American Studies 46', 'Philosophy 5', 'Political Science 51', 'Psychology 41', 'Sociology 46A', 'Sociology 46B', 'Statistics 13']
# ------------------
# Chemical Physics Major
# http://catalog.ucdavis.edu/programs/CHE/CHEreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C']
# ------------------
# Chemistry Major
# http://catalog.ucdavis.edu/programs/CHE/CHEreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C']
# ------------------
# Chicana/Chicano Studies Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/CHI/CHIreqt.html
# ['Chicana/o Studies 10', 'Chicana/o Studies 50', 'Chicana/o Studies 21', 'Chicana/o Studies 40', 'One of Chicana/o Studies 60', 'One of Chicana/o Studies 65', 'One of Chicana/o Studies 70', 'One of Chicana/o Studies 73', 'Spanish 1', 'Spanish 2', 'Spanish 3', 'Spanish 28', 'Spanish 31', 'Spanish 32']
# ------------------
# Chinese Major
# http://catalog.ucdavis.edu/programs/EAC/EACreqt.html#Chinese
# ['Chinese 1', 'Chinese 2', 'Chinese 3', 'Chinese 4', 'Chinese 5', 'Chinese 6', 'OR 1BL', 'OR 2BL', 'OR 3BL', 'OR 1CN', 'OR 2CN', 'OR 3CN', 'Chinese 10', 'Chinese 11', 'Chinese 50', 'Comparative Literature 14', 'Japanese 10', 'Linguistics 1', 'History 9A.']
# ------------------
# Cinema and Digital Media Major
# http://catalog.ucdavis.edu/programs/CTS/CTSreqt.html
# ['Film Studies 1', 'Technocultural Studies 1', 'Technocultural Studies 5', 'Cinema and Technocultural Studies 12', 'Cinema and Technocultural Studies 20', 'Cinema and Technocultural Studies 40A', 'Cinema and Technocultural Studies 40B', 'Cinema and Technocultural Studies 41A', 'Cinema and Technocultural Studies 41B', 'Film Studies 45']
# ------------------
# Classical Civilization Major
# http://catalog.ucdavis.edu/programs/CLA/CLAcourses.html
# []
# ------------------
# Cognitive Science Major
# http://cogsci.ucdavis.edu/program.html
# []
# ------------------
# Communication Major
# http://catalog.ucdavis.edu/programs/CMN/CMNreqt.html
# ['Anthropology 4', 'Linguistics 1', 'Communication 10Y', 'Communication 1', 'Communication 3', 'Communication 5/Linguistics', 'Communication 5', 'Computer Science 15', 'Philosophy 12', 'Psychology 1', 'Sociology 1', 'Statistics 13', 'Sociology 46B']
# ------------------
# Comparative Literature Major
# http://catalog.ucdavis.edu/programs/COM/COMreqt.html
# ['Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'from excluding the 10', 'It is recommended that students who do not use a European language toward the major take one of the remaining required lower division courses in the 53', 'It is recommended that students who do not use a European language toward the major take one of the remaining required lower division courses in the series, preferably the 53']
# ------------------
# Computer Science Major
# http://catalog.ucdavis.edu/programs/compsci/compscireqt.html
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 22A', 'Mathematics 67', 'Computer Science Engineering 20', 'Computer Science Engineering 30', 'Computer Science Engineering 40', 'Computer Science Engineering 60', 'Computer Science Engineering 50', 'Electrical and Computer Engineering 70', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2A', 'Chemistry 2B', 'Biological Sciences 2A', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 21D']
# ------------------
# Design Major
# http://catalog.ucdavis.edu/programs/DES/DESreqt.html
# ['Design 1', 'Art 2', 'Design 14', 'Design 15', 'Design 16', 'University Writing Program 11', 'University Writing Program 18', 'University Writing Program 19', 'Design 40A', 'Design 40B', 'Design 40C', 'Design 21', 'Design 31', 'Design 37', 'Design 50', 'Design 60', 'Design 70', 'Design 77', 'Art 9']
# ------------------
# East Asian Studies Major
# http://catalog.ucdavis.edu/programs/EAS/EASreqt.html
# ['History 9A', 'History 9B', 'Art History 1D', 'Chinese 7', 'Chinese 10', 'Chinese 11', 'Comparative Literature 53A', 'East Asian Studies 88', 'Japanese 10', 'Japanese 25', 'Japanese 50', 'Religious Studies, 75']
# ------------------
# Economics Major
# http://catalog.ucdavis.edu/programs/ECN/ECNreqt.html
# ['Economics 1A', 'Economics 1B', 'Statistics 13', 'Statistics 32', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 21A', 'Mathematics 21B']
# ------------------
# English Major
# http://catalog.ucdavis.edu/programs/ENL/ENLreqt.html
# ['English 3', 'University Writing Program 1', 'English 40', 'English 43', 'English 44', 'English 45', 'English 10A', 'English 10B', 'English 10C']
# ------------------
# French Major
# http://registrar.ucdavis.edu/UCDWebCatalog/Programs/FRE/FREreqt.html
# ['French 1', 'French 2', 'French 3', 'French 21', 'French 22', 'French 23', 'Linguistics 1', 'Linguistics 4']
# ------------------
# Gender, Sexuality and Women's Studies Major
# http://catalog.ucdavis.edu/programs/WMS/WMSreqt.html
# ['Women\x92s Studies, 50', 'Women\x92s Studies, 60', 'Women\x92s Studies, 70', 'African American and African Studies 10', 'African American and African Studies 17', 'American Studies 21', 'American Studies 30', 'Anthropology 2', 'Anthropology 20', 'Anthropology 30', 'Asian American Studies 1', 'Asian American Studies 2', 'Chicana/o Studies 10', 'Chicana/o Studies 21S', 'Chicana/o Studies 50', 'Comparative Literature 12', 'Dramatic Art 1', 'English 3', 'History 72A', 'History 72B', 'History 85', 'Native American Studies 10', 'Native American Studies 32', 'Political Science 7', 'Psychology 1', 'Science and Technology 12', 'Science and Technology 20', 'Science and Technology 32', 'Sociology 2', 'Sociology 3', 'Sociology 11', 'Sociology 30A', 'Sociology 30B', 'Textiles and Clothing 7', 'Undergraduate Writing Program 19', 'Women\x92s Studies 20', 'Women\x92s Studies 80']
# ------------------
# Geology Major
# http://catalog.ucdavis.edu/programs/EPS/EPSreqt.html
# ['Geology 3', 'Geology 3L', 'Geology 50', 'Geology 50L', 'Geology 60', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 21A', 'Mathematics 21B', 'Chemistry 2A', 'Chemistry 2B', 'Physics 7A', 'Physics 7B', 'Statistics 13', 'Statistics 13V', 'Statistics 32']
# ------------------
# German Major
# http://catalog.ucdavis.edu/Programs/GER/GERreqt.html
# ['German 20', 'German 21', 'German 22']
# ------------------
# History Major
# http://catalog.ucdavis.edu/Programs/HIS/HISreqt.html
# []
# ------------------
# International Relations Major
# http://catalog.ucdavis.edu/Programs/POL/POLreqt.html#IRE
# ['1', '2', '3', '4', '5', 'Political Science 51', 'Statistics 13', 'Statistics 32']
# ------------------
# Italian Major
# http://catalog.ucdavis.edu/Programs/ITA/ITAreqt.html
# ['Italian 1', 'Italian 2', 'Italian 3', 'Italian 4', 'Italian 5', 'Italian 9']
# ------------------
# Japanese Major
# http://catalog.ucdavis.edu/Programs/EAC/EACreqt.html
# ['Chinese 1', 'Chinese 2', 'Chinese 3', 'Chinese 4', 'Chinese 5', 'Chinese 6', 'OR 1BL', 'OR 2BL', 'OR 3BL', 'OR 1CN', 'OR 2CN', 'OR 3CN', 'Chinese 10', 'Chinese 11', 'Chinese 50', 'Comparative Literature 14', 'Japanese 10', 'Linguistics 1', 'History 9A.']
# ------------------
# Linguistics Major
# http://catalog.ucdavis.edu/Programs/LIN/LINreqt.html
# ['Linguistics 1']
# ------------------
# Marine and Coastal Science—Oceans and the Earth System
# http://catalog.ucdavis.edu/programs/MCS/MCSreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 8A', 'Chemistry 8B', 'Evolution & Ecology 12', 'Geology 16']
# ------------------
# Mathematical Analytics and Operations Research Major
# http://catalog.ucdavis.edu/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Mathematical and Scientific Computation Major
# http://catalog.ucdavis.edu/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Mathematics Major
# http://catalog.ucdavis.edu/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Medieval and Early Modern Studies Major
# http://catalog.ucdavis.edu/Programs/MST/MSTreqt.html
# ['Medieval Studies 20A', 'Medieval Studies 20B', 'Art History 1B', 'Art History 1C', 'Art History 1E', 'Comparative Literature 2', 'Comparative Literature 10A', 'Comparative Literature 10B', 'Comparative Literature 10C', 'Comparative Literature 10D', 'Comparative Literature 10E', 'English 10A', 'German 48', 'History 4A', 'History 4B', 'Humanities 1*', 'Humanities 9', 'Philosophy 21', 'Philosophy 22']
# ------------------
# Middle East/South Asia Studies Major
# http://catalog.ucdavis.edu/programs/MSA/MSAreqt.html
# ['History 6', 'History 8', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 1', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 2', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 3', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 21', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 22', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 23', 'Hebrew 1', 'Hebrew 2', 'Hebrew 3', 'Hebrew 21', 'Hebrew 22', 'Hebrew 23', 'Hindi/Urdu 1', 'Hindi/Urdu 2', 'Hindi/Urdu 3', 'Hindi/Urdu 21', 'Hindi/Urdu 22', 'Hindi/Urdu 23']
# ------------------
# Music Major
# http://catalog.ucdavis.edu/Programs/MUS/MUSreqt.html
# ['Music 6A', 'Music 6B', 'Music 6C', 'Plus Music 2A', 'Plus Music 2B', 'Plus Music 2C', 'And Music 16A', 'And Music 16B', 'And Music 16C', 'Music 7A', 'Music 7B', 'Music 7C', 'Plus Music 17A', 'Plus Music 17B', 'Plus Music 17C', 'Music 24A', 'Music 24B', 'Music 24C']
# ------------------
# Native American Studies Major
# http://catalog.ucdavis.edu/Programs/NAS/NASreqt.html
# ['Native American Studies 1', 'Native American Studies 10', 'Native American Studies 12', 'Native American Studies 5', 'Native American Studies 12', 'Native American Studies 32', 'Native American Studies 33', 'Native American Studies 34', 'African American and African Studies 12', 'African American and African Studies 52', 'Anthropology 2', 'Anthropology 20', 'Anthropology 24', 'Asian American Studies 1', 'Asian American Studies 2', 'Asian American Studies 4', 'Chicana/o Studies 10', 'Chicana/o Studies 21', 'Chicana/o Studies 23', 'Comparative Literature 25', 'Community and Regional Development 2', 'Environmental Science and Policy 10', 'History 7A', 'History 7B', 'History 7C', 'History 17A', 'Linguistics 1', 'Religious Studies 90', 'Technocultural Studies 2']
# ------------------
# Pharmaceutical Chemistry Major
# http://catalog.ucdavis.edu/programs/CHE/CHEreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C']
# ------------------
# Philosophy Major
# http://catalog.ucdavis.edu/Programs/PHI/PHIreqt.html
# ['Philosophy 1', 'Philosophy 21', 'Philosophy 22', 'Philosophy 13G', 'Philosophy 14', 'Philosophy 15', 'Philosophy 24', 'Philosophy 30', 'Philosophy 31', 'Philosophy 32', 'Philosophy 38', 'Philosophy 17', 'Philosophy 12']
# ------------------
# Physics Major
# http://catalog.ucdavis.edu/Programs/PHY/PHYreqt.html
# ['Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Physics 9HA', 'Physics 9HB', 'Physics 9HC', 'Physics 9HD', 'Physics 9HE', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B']
# ------------------
# Political Science Major
# http://catalog.ucdavis.edu/Programs/POL/POLreqt.html#Political
# ['1', '2', '3', '4', '5', 'Political Science 51', 'Statistics 13', 'Statistics 32']
# ------------------
# Political Science – Public Service  Major
# http://catalog.ucdavis.edu/Programs/POL/POLreqt.html#Public
# ['1', '2', '3', '4', '5', 'Political Science 51', 'Statistics 13', 'Statistics 32']
# ------------------
# Psychology Major
# http://catalog.ucdavis.edu/Programs/PSC/PSCreqt.html
# ['Psychology 1', 'Psychology 41', 'Statistics 13', 'Strongly recommended that Psychology 41', 'Statistics 13', 'Biological Sciences 2A', 'Biological Sciences 10', 'Anthropology 1', 'Molecular and Cellular Biology 10', 'Neurobiology, Physiology, and Behavior 10']
# ------------------
# Religious Studies Major
# http://catalog.ucdavis.edu/Programs/RST/RSTreqt.html
# ['One course from the Religious Studies 1']
# ------------------
# Russian Major
# http://catalog.ucdavis.edu/Programs/RUS/RUSreqt.html
# []
# ------------------
# Science and Technology Studies Major
# http://catalog.ucdavis.edu/programs/STS/STSreqt.html
# ['Science and Technology Studies 1', 'Science and Technology Studies 20', 'Eight units selected from American Studies 1A', 'Eight units selected from American Studies 1E', 'Eight units selected from American Studies 5', 'Environmental Studies 1', 'Humanities 3', 'Philosophy 30', 'Philosophy 31', 'Philosophy 32', 'Science and Society 1', 'Science and Society 2', 'Science and Society 3', 'Science and Society 5', 'Science and Technology Studies 32']
# ------------------
# Sociology Major
# http://catalog.ucdavis.edu/Programs/SOC/SOCreqt.html
# ['Sociology 1', 'Sociology 46A', 'Sociology 46B', 'Sociology 2', 'Sociology 3', 'Sociology 4', 'Sociology 5', 'Sociology 11', 'Sociology 25', 'Sociology 30A', 'Sociology 30B', 'Anthropology 2', 'Anthropology 20', 'Select from History 4A', 'Select from History 4B', 'Select from History 4C', 'Select from History 6', 'Select from History 7A', 'Select from History 7B', 'Select from History 7C', 'Select from History 8', 'Select from History 9A', 'Select from History 9B', 'Select from History 10C', 'Select from History 15', 'Select from History 17A', 'Select from History 17B', 'Select from Philosophy 5', 'Select from Philosophy 14', 'Select from Philosophy 24']
# ------------------
# Sociology – Organizational Studies Major
# http://catalog.ucdavis.edu/Programs/SOC/SOCreqt.html#Org
# ['Sociology 1', 'Sociology 46A', 'Sociology 46B', 'Sociology 2', 'Sociology 3', 'Sociology 4', 'Sociology 5', 'Sociology 11', 'Sociology 25', 'Sociology 30A', 'Sociology 30B', 'Anthropology 2', 'Anthropology 20', 'Select from History 4A', 'Select from History 4B', 'Select from History 4C', 'Select from History 6', 'Select from History 7A', 'Select from History 7B', 'Select from History 7C', 'Select from History 8', 'Select from History 9A', 'Select from History 9B', 'Select from History 10C', 'Select from History 15', 'Select from History 17A', 'Select from History 17B', 'Select from Philosophy 5', 'Select from Philosophy 14', 'Select from Philosophy 24']
# ------------------
# Spanish Major
# http://catalog.ucdavis.edu/programs/SPA/SPAreqt.html
# ['Spanish 1', 'Spanish 2', 'Spanish 3', 'Spanish 21', 'Spanish 21S', 'Spanish 22', 'Spanish 22S', 'Spanish 23', 'Spanish 23S', 'Spanish 24', 'Spanish 24S', 'Spanish 31', 'Spanish 32', 'Spanish 33', 'Linguistics 1']
# ------------------
# Statistics Major
# http://catalog.ucdavis.edu/programs/STA/STAreqt.html
# ['Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 22A', 'Computer Science Engineering 30', 'Computer Science Engineering 40', 'Statistics 32']
# ------------------
# Theatre and Dance Major
# http://catalog.ucdavis.edu/programs/DRA/DRAreqt.html
# ['Dramatic Art 28', 'Dramatic Art 55', 'Dramatic Art 56A', 'Dramatic Art 56B', 'Dramatic Art 56C']
# ------------------
# Lower-division prerequisite list for the Agriculture and Environmental Sciences:
# Agricultural and Environmental Education Major
# http://catalog.ucdavis.edu/programs/AED/AEDmajor.html
# ['Animal Science 1', 'Animal Science 2', 'Animal Science 21', 'Animal Science 41', 'Applied Biological Systems Technology 16', 'Applied Biological Systems Technology 52', 'Applied Biological Systems Technology 49', 'Agricultural & Resource Economics 15', 'Economics 1A', 'Economics 1B', 'Environmental Horticulture 1', 'Environmental Horticulture 6', 'Plant Sciences 5', 'Environmental Science and Policy 10', 'Environmental Toxicology 10', 'Hydrologic Science 10', 'Hydrologic Science 47', 'Plant Sciences 1', 'Plant Sciences 2', 'Plant Sciences 15', 'Plant Sciences 49', 'Viticulture and Enology 2', 'Viticulture and Enology 3', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Chemistry 2A', 'Chemistry 2B', 'Geology 1', 'Geology 20', 'Soil Science 10', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Physics 7A', 'Physics 7B']
# ------------------
# Animal Biology Major
# http://catalog.ucdavis.edu/programs/ABI/ABIreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Chemistry 118A', 'Chemistry 118B', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Statistics 13', 'Animal Biology 50A', 'Animal Biology 50B', 'Animal Biology 50C']
# ------------------
# Animal Science and Management Major
# http://catalog.ucdavis.edu/programs/ASM/ASMreqt.html
# ['Animal Science 1', 'Animal Science 2', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Plant Sciences 21', 'Computer Science Engineering 15', 'Economics 1A', 'Economics 1B', 'Management 11A', 'Management 11B', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C']
# ------------------
# Animal Science Major
# http://catalog.ucdavis.edu/programs/ANS/ANSreqt.html
# ['Animal Science 1', 'Animal Science 2', 'Animal Science 41', 'Animal Science 41L', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B']
# ------------------
# Atmospheric Science Major
# http://catalog.ucdavis.edu/programs/ATM/ATMreqt.html
# ['Plant Sciences 2', 'Chemistry 2A', 'Chemistry 2B', 'Computer Science Engineering 30', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Atmospheric Science 60', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Statistics 13']
# ------------------
# Biotechnology Major
# http://catalog.ucdavis.edu/programs/BIT/BITreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Physics 7A', 'Physics 7B', 'Biotechnology 1']
# ------------------
# Clinical Nutrition Major
# http://catalog.ucdavis.edu/programs/clinut/clinutreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Economics 1A', 'Economics 1B', 'Psychology 1', 'Sociology 1', 'Sociology 3', 'Anthropology 2', 'Statistics 13']
# ------------------
# Community and Regional Development Major
# http://catalog.ucdavis.edu/programs/CRD/CRDreqt.html
# ['Community and Regional Development 1', 'Community and Regional Development 2', 'Plant Sciences 21', 'Computer Science Engineering 15', 'Economics 1A', 'Economics 1B', 'Anthropology 2', 'Sociology 1', 'Statistics 13', 'Statistics 32', 'Sociology 46B']
# ------------------
# Ecological Management and Restoration Major
# http://catalog.ucdavis.edu/programs/EMR/EMRreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Physics 1A', 'Physics 1B', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Environmental Science and Policy 1']
# ------------------
# Entomology Major
# http://catalog.ucdavis.edu/programs/ENT/ENTreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 1A', 'Physics 1B', 'Statistics 13', 'Statistics 32', 'Plant Sciences 21', 'Engineering 5']
# ------------------
# Environmental Horticulture and Urban Forestry Major
# http://catalog.ucdavis.edu/programs/ehuf/ehufreqt.html
# ['Environmental Horticulture 1', 'Environmental Horticulture 6', 'Landscape Architecture 30', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Plant Sciences 2', 'Chemistry 2A', 'Chemistry 2B', 'Environmental Science and Policy 1', 'Environmental Science and Policy 10', 'Environmental Science and Policy 30', 'Physics 1A', 'Physics 1B', 'Plant Sciences 21', 'Mathematics 16A', 'Statistics 13', 'Select one lower division resource science course and one lower division social science/humanities course in consultation with adviser; minimum 6']
# ------------------
# Environmental Policy Analysis and Planning Major
# http://catalog.ucdavis.edu/programs/envpol/envpolreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 10', 'Biological Sciences 10V', 'Chemistry 2A', 'Chemistry 10', 'Physics 1A', 'Biological Sciences 2B', 'Chemistry 2B', 'Physics 1B', 'Plant Sciences 21', 'Science & Society 18', 'Economics 1A', 'Economics 1B', 'Animal Science 1', 'Atmospheric Science 60', 'Geology 1', 'Plant Sciences 12', 'Wildlife, Fish, & Conservation Biology 11', 'Environmental Science & Policy 1', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Political Science 1', 'Statistics 13', 'Statistics 32']
# ------------------
# Environmental Science and Management Major
# http://catalog.ucdavis.edu/programs/ESM/ESMreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Geology 1', 'Geology 50', '50', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2AH', 'Chemistry 2BH', '2C', '2CH', 'Physics 1A', 'Physics 1B', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Economics 1A', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', '17A', '17B', 'Environmental Science and Policy 1']
# ------------------
# Environmental Toxicology Major
# http://catalog.ucdavis.edu/programs/ETX/ETXreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Chemistry 118A', 'Chemistry 118B', 'Chemistry 118C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C']
# ------------------
# Fiber and Polymer Science Major (suspended 2017-20)
# http://catalog.ucdavis.edu/Programs/FPS/FPSreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Computer Science Engineering 15', 'Computer Science Engineering 30', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Statistics 13', 'Textiles and Clothing 6', 'Textiles and Clothing 8', 'Engineering 45']
# ------------------
# Food Science Major
# http://catalog.ucdavis.edu/Programs/foodsci/foodscireqt.html
# ['Communication 1', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Biological Sciences 2A', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Food Science and Technology 50', 'Nutrition 10']
# ------------------
# Global Disease Biology Major
# http://gdb.ucdavis.edu/majorrequirements.cfm
# []
# ------------------
# Human Development Major
# http://catalog.ucdavis.edu/Programs/HDE/HDEreqt.html
# ['Anthropology 1', 'Anthropology 1Y', 'Anthropology 2', 'Anthropology 15', 'Biological Sciences 2A', 'Biological Sciences 10', 'Biological Sciences 10V', 'Microbiology 10', 'Neurobiology, Physiology, and Behavior 12', 'Molecular and Cellular Biology 10', 'History 17A', 'History 17B', 'History 72A', 'History 72B', 'Political Science 1', 'Philosophy 5', 'Philosophy 15', 'Philosophy 30', 'Philosophy 31', 'Philosophy 32', 'Philosophy 38', 'Neurobiology, Physiology, and Behavior 10', 'Psychology 1', 'Psychology 41', 'Sociology 46A', 'Sociology 46B', 'Statistics 10', 'Statistics 13', 'Statistics 13V']
# ------------------
# Hydrology Major
# http://catalog.ucdavis.edu/Programs/HYD/HYDreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Geology 50', 'Geology 50L', 'Engineering 6']
# ------------------
# International Agricultural Development Major
# http://catalog.ucdavis.edu/Programs/IAD/IADreqt.html
# ['International Agricultural Development 10', 'Plant Sciences 2', 'Soil Sciences 10', 'Economics 1A', 'Economics 1B', 'Statistics 13', 'Sociology 46B', 'Math 16A', 'Community and Regional Development 1', 'Agricultural and Resource Economics 15', 'Animal Science 41', 'Animal Science 41L', 'Community and Regional Development 20', 'Nutrition 10', 'Plant Sciences 1', 'Plant Sciences 15', 'Plant Sciences 49']
# ------------------
# Landscape Architecture Major
# http://catalog.ucdavis.edu/Programs/LDA/LDAreqt.html
# ['Communication 1', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Environmental Horticulture 6', 'Mathematics 16A', 'Statistics 13', 'Computer Science 10', 'Chemistry 2A', 'Chemistry 10', 'Physics 1A', 'Physics 10', 'Geology 1', 'Geography 1', 'Soil Science 10', 'Landscape Architecture 1', 'Landscape Architecture 2', 'Landscape Architecture 3', 'Landscape Architecture 21', 'Landscape Architecture 30', 'Landscape Architecture 50', 'Landscape Architecture 60', 'Landscape Architecture 70']
# ------------------
# Managerial Economics Major
# http://catalog.ucdavis.edu/Programs/mecon/meconreqt.html
# ['Agricultural and Resource Economics 18', 'Economics 1A', 'Economics 1B', 'Plant Sciences 21', 'Engineering Computer Science 10', 'Engineering Computer Science 15', 'Engineering Computer Science 30', 'Management 11A', 'Management 11B', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Statistics 13']
# ------------------
# Marine and Coastal Science—Coastal Environmental Processes or Marine Environmental Chemistry Major
# http://catalog.ucdavis.edu/programs/MCS/MCSreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 8A', 'Chemistry 8B', 'Evolution & Ecology 12', 'Geology 16']
# ------------------
# Nutrition Science Major
# http://catalog.ucdavis.edu/Programs/nutsci/nutscireqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Chemistry 118A', 'Chemistry 118B', 'Nutrition 10', 'Sociology 46A', 'Psychology 41', 'Anthropology 2', 'Psychology 1', 'Sociology 1', 'Sociology 3', 'Mathematics 16A', 'Mathematics 16B', 'Physics 1A', 'Physics 1B', 'Anthropology 2', 'Sociology 1', 'Sociology 3', 'Economics 1A', 'Economics 1B', 'Psychology 1']
# ------------------
# Plant Sciences Major
# http://catalog.ucdavis.edu/programs/PLS/PLSreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Plant Sciences 2', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Physics 1A', 'Physics 1B', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 17A', 'Mathematics 17B', 'Applied Biological Systems Technology 49', 'Plant Sciences 49']
# ------------------
# Sustainable Agriculture and Food Systems Major
# http://catalog.ucdavis.edu/programs/SAFS/SAFSreqt.html
# ['Mathematics 16A', 'Mathematics 16B', 'Chemistry 2A', 'Chemistry 2B', 'Physics 1A', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Plant Sciences 2', 'Animal Sciences 1', 'Animal Sciences 2', 'Food Science 1', 'Economics 1A', 'Community and Regional Development 1', 'Philosophy 14', 'Philosophy 15', 'Philosophy 24', 'Anthropology 2', 'Political Science 4', 'Sociology 1', 'Sociology 3']
# ------------------
# Sustainable Environmental Design Major
# http://catalog.ucdavis.edu/programs/SED/SEDreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Landscape Architecture 1', 'Landscape Architecture 2', 'Landscape Architecture 3', 'Landscape Architecture 21', 'Landscape Architecture 30', 'Landscape Architecture 50', 'Landscape Architecture 70']
# ------------------
# Textiles and Clothing Major (suspended 2018-20)
# http://catalog.ucdavis.edu/programs/TXC/TXCreqt.html
# ['Plant Sciences 21', 'Computer Science Engineering 15', 'Computer Science Engineering 30', 'Economics 1A', 'Economics 1B', 'Anthropology 2', 'Science and Society 1', 'Art History 1A', 'Art History 1B', 'Art History 1C', 'Art History 1D', 'Physics 1A', 'Physics 10', 'Psychology 1', 'Sociology 2', 'Statistics 13', 'Textiles and Clothing 6', 'Textiles and Clothing 7', 'Textiles and Clothing 8', 'Management 11A', 'Management 11B', 'Chemistry 10', 'Chemistry 2A', 'Mathematics 16A', 'Mathematics 16B']
# ------------------
# Viticulture and Enology Major
# http://catalog.ucdavis.edu/programs/VEN/VENreqt.html
# ['Biological Sciences 1A', 'Biological Sciences 2A', 'Biological Sciences 1C', 'Plant Sciences 2', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Plant Sciences 21', 'Mathematics 16A', 'Mathematics 16B', 'Physics 1A', 'Physics 1B', 'Physics 7A', 'Viticulture and Enology 2', 'Viticulture and Enology 3']
# ------------------
# Wildlife, Fish and Conservation Biology Major
# http://catalog.ucdavis.edu/programs/WFC/WFCreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Mathematics 16A', 'Mathematics 16B', 'Physics 1A', 'Physics 1B', 'Wildlife, Fish, and Conservation Biology 10', 'Wildlife, Fish, and Conservation Biology 11', 'Wildlife, Fish, and Conservation Biology 50']
# ------------------
# Lower-division prerequisite list for the College of Engineering:
# Aerospace Science and Engineering Major
# http://catalog.ucdavis.edu/programs/EME/EMEreqt.html#aero
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2AH', 'Chemistry 2BH', 'Engineering 4', 'Engineering 6', 'Mechanical Engineering 5', 'Engineering 17', 'Engineering 35', 'Engineering 45', '45Y).', 'Mechanical Engineering 50', 'English 3', 'UniversityWriting Program 1', 'UniversityWriting Program 1Y', 'UniversityWriting Program 1V', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5', 'Communication 1', 'Communication 3']
# ------------------
# Biochemical Engineering Major
# http://catalog.ucdavis.edu/programs/ECH/ECHreqt.html#biochemeng
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Chemical Engineering and Materials Science 5', 'Chemical Engineering and Materials Science 6', 'Chemical Engineering and Materials Science 51', 'Chemical Engineering and Materials Science 80', 'Engineering 45', 'Engineering 45Y', 'Biotechnology 1', 'Biotechnology 1Y', 'Biological Sciences 2A', 'English 3', 'University Writing Program 1', 'University Writing Program 1V', 'University Writing Program 1Y', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5']
# ------------------
# Biological Systems Engineering Major
# http://catalog.ucdavis.edu/programs/EBA/EBAreqt.html#Biological
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 2A', 'Chemistry 2B', 'Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Engineering 6', 'Engineering 35', 'Engineering 17', 'Biological Systems Engineering 1', 'Biological Systems Engineering 75', 'University Writing Program 1', 'University Writing Program 1Y', 'University Writing Program 1V', 'Communication 1', 'Communication 3']
# ------------------
# Biomedical Engineering Major
# http://catalog.ucdavis.edu/programs/BIM/BIMreqt.html
# ['Mathematics 21A', 'Mathematics 21AH', 'Mathematics 21B', 'Mathematics 21BH', 'Mathematics 21C', 'Mathematics 21CH', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9HA', 'Physics 99BC', 'Chemistry 2A', 'Chemistry 2AH', 'Chemistry 2B', 'Chemistry 2BH', 'Chemistry 2C', 'Chemistry 2CH', 'Chemistry 8A', 'Chemistry 8B', 'Engineering 6', 'Engineering 17', 'University Writing Program 1', 'University Writing Program 1Y', 'University Writing Program 1V', 'English 3', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5', 'Biological Sciences 2A', 'Biomedical Engineering 1', 'Biomedical Engineering 20']
# ------------------
# Chemical Engineering Major
# http://catalog.ucdavis.edu/programs/ECH/ECHreqt.html#Chemical
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Chemical Engineering and Materials Science 5', 'Chemical Engineering and Materials Science 6', 'Chemical Engineering and Materials Science 51', 'Chemical Engineering and Materials Science 80', 'Engineering 45', 'Engineering 45Y', 'Biotechnology 1', 'Biotechnology 1Y', 'Biological Sciences 2A', 'English 3', 'University Writing Program 1', 'University Writing Program 1V', 'University Writing Program 1Y', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5']
# ------------------
# Civil Engineering Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ECI/ECIcourses.html
# []
# ------------------
# Computer Engineering Major
# http://catalog.ucdavis.edu/programs/EEC/EECreqt.html#Computer
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Chemistry 2A', 'Computer Science Engineering 30', 'Engineering 6', 'Engineering 17', 'Electrical and Computer Engineering 1', 'Electrical and Computer Engineering 10', 'and Computer Engineering 10', 'Transfer and change of major students who do not take Electrical and Computer Engineering 10', 'English 3', 'University Writing Program 1', 'University Writing Program 1Y', 'University Writing Program 1V', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5', 'Communication 1', 'Communication 3']
# ------------------
# Computer Science and Engineering Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ECS/ECSreqt.html
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 67', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Chemistry 2A', 'Computer Science Engineering 20', 'Computer Science Engineering 30', 'Computer Science Engineering 40', 'Computer Science Engineering 60', 'Computer Science Engineering 50', 'Electrical and Computer Engineering 70', 'Engineering 17', 'English 3', 'University Writing Program 1', 'University Writing Program 1V', 'University Writing Program 1Y', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5', 'Communication 1']
# ------------------
# Electrical Engineering Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/EEC/EECreqt.html
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Chemistry 2A', 'Computer Science Engineering 30', 'Engineering 6', 'Engineering 17', 'Electrical and Computer Engineering 1', 'Electrical and Computer Engineering 10', 'and Computer Engineering 10', 'Transfer and change of major students who do not take Electrical and Computer Engineering 10', 'English 3', 'University Writing Program 1', 'University Writing Program 1Y', 'University Writing Program 1V', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5', 'Communication 1', 'Communication 3']
# ------------------
# Materials Science and Engineering Major
# http://catalog.ucdavis.edu/programs/ECH/ECHreqt.html#Materials1
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Chemical Engineering and Materials Science 5', 'Chemical Engineering and Materials Science 6', 'Chemical Engineering and Materials Science 51', 'Chemical Engineering and Materials Science 80', 'Engineering 45', 'Engineering 45Y', 'Biotechnology 1', 'Biotechnology 1Y', 'Biological Sciences 2A', 'English 3', 'University Writing Program 1', 'University Writing Program 1V', 'University Writing Program 1Y', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5']
# ------------------
# Mechanical Engineering Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/EME/EMEreqt.html
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2AH', 'Chemistry 2BH', 'Engineering 4', 'Engineering 6', 'Mechanical Engineering 5', 'Engineering 17', 'Engineering 35', 'Engineering 45', '45Y).', 'Mechanical Engineering 50', 'English 3', 'UniversityWriting Program 1', 'UniversityWriting Program 1Y', 'UniversityWriting Program 1V', 'Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'Native American Studies 5', 'Communication 1', 'Communication 3']
# ------------------
# Lower-division prerequisite list for the College of Biological Sciences:
# Biochemistry and Molecular Biology Major
# http://catalog.ucdavis.edu/programs/MCB/MCBreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Physics 7A', 'Physics 7B', 'Physics 7C']
# ------------------
# Biological Sciences Major
# http://catalog.ucdavis.edu/programs/BIS/BISreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Chemistry 118A', 'Chemistry 118B', 'Chemistry 118C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Physics 1A', 'Physics 1B', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Chemistry 2C', 'Math 17C', 'Math 21C)']
# ------------------
# Cell Biology Major
# http://catalog.ucdavis.edu/programs/MCB/MCBreqt.html#Cell
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Physics 7A', 'Physics 7B', 'Physics 7C']
# ------------------
# Evolution, Ecology and Biodiversity Major
# http://catalog.ucdavis.edu/programs/EVE/EVEreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Mathematics 17A', 'Mathematics 17B', 'recommended) 21A', 'recommended) 21B', 'Physics 1A', 'Physics 1B']
# ------------------
# Genetics and Genomics Major
# http://catalog.ucdavis.edu/programs/MCB/MCBreqt.html#Genetics
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Physics 7A', 'Physics 7B', 'Physics 7C']
# ------------------
# Marine and Coastal Science—Marine Ecology and Organismal Biology Major
# http://catalog.ucdavis.edu/programs/MCS/MCSreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 8A', 'Chemistry 8B', 'Evolution & Ecology 12', 'Geology 16']
# ------------------
# Microbiology Major
# http://catalog.ucdavis.edu/programs/MIC/MICreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Chemistry 118A', 'Chemistry 118B', 'Chemistry 118C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 21A', 'Mathematics 21B', 'Physics 1A', 'Physics 1B', 'Physics 7A', 'Physics 7B', 'Physics 7C']
# ------------------
# Neurobiology, Physiology and Behavior Major
# http://catalog.ucdavis.edu/programs/NPB/NPBreqt.html#Neurobiology
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 8A', 'Chemistry 8B', 'Chemistry 118A', 'Chemistry 118B', 'Chemistry 118C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Physics 7A', 'Physics 7B', 'Physics 7C']
# ------------------
# Plant Biology Major
# http://catalog.ucdavis.edu/programs/PLB/PLBreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 8A', 'Chemistry 8B', 'Statistics 13']
# ------------------
# [['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 2C',
#   'Chemistry 2AH',
#   'Chemistry 2BH',
#   'Chemistry 2CH',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 17C',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 8A',
#   'Chemistry 8B',
#   'Chemistry 118A',
#   'Chemistry 118B',
#   'Chemistry 118C',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Physics 1A',
#   'Physics 1B',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C',
#   'Chemistry 2C',
#   'Math 17C',
#   'Math 21C)'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 2C',
#   'Chemistry 2AH',
#   'Chemistry 2BH',
#   'Chemistry 2CH',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 17C',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 8A',
#   'Chemistry 8B',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'recommended) 21A',
#   'recommended) 21B',
#   'Physics 1A',
#   'Physics 1B'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 2C',
#   'Chemistry 2AH',
#   'Chemistry 2BH',
#   'Chemistry 2CH',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 17C',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 2C',
#   'Mathematics 16A',
#   'Mathematics 16B',
#   'Mathematics 16C',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 17C',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Mathematics 21C',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C',
#   'Physics 9A',
#   'Physics 9B',
#   'Physics 9C',
#   'Chemistry 8A',
#   'Chemistry 8B',
#   'Evolution & Ecology 12',
#   'Geology 16'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 8A',
#   'Chemistry 8B',
#   'Chemistry 118A',
#   'Chemistry 118B',
#   'Chemistry 118C',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Physics 1A',
#   'Physics 1B',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 2C',
#   'Chemistry 8A',
#   'Chemistry 8B',
#   'Chemistry 118A',
#   'Chemistry 118B',
#   'Chemistry 118C',
#   'Mathematics 17A',
#   'Mathematics 17B',
#   'Mathematics 17C',
#   'Mathematics 21A',
#   'Mathematics 21B',
#   'Physics 7A',
#   'Physics 7B',
#   'Physics 7C'],
#  ['Biological Sciences 2A',
#   'Biological Sciences 2B',
#   'Biological Sciences 2C',
#   'Chemistry 2A',
#   'Chemistry 2B',
#   'Chemistry 8A',
#   'Chemistry 8B',
#   'Statistics 13']]

# %% [markdown]
# The next step is to sort all of the majors in the College of Letters and Science into one of four "undeclared" categories. This is because entering "undeclared" students in the College of Letters and Science must be in one of four general subject areas: Fine Arts, Humanties, Social Sciences, or Physical Sciences. The suggested courses will be different depending on which area a student has chosen to further explore.

# %%
# Create lists of keywords for each subject area in Letters and Sciences

fineArtsKeywordList = ['Art','Theater','Cinema','Theatre','Music']
socialSciencesKeywordList = ['Econ','Political','International','Soci','Anthro','Psych']
mathPhysicalSciencesKeywordList = ['Math','Physic','Stat','Chem','Computer','Geology','Marine','Tech']

# This sorts each of the majors into one of the four undeclared categories based on keywords defined above
fineArtsMajorList = []
socialSciencesMajorList = []
mathPhysicalSciencesMajorList = []
humanitiesMajorList = []
for major in lsList:
    if any(keyword in major[0] for keyword in fineArtsKeywordList):
        fineArtsMajorList.append(major)
    elif any(keyword in major[0] for keyword in socialSciencesKeywordList):
        socialSciencesMajorList.append(major)
    elif any(keyword in major[0] for keyword in mathPhysicalSciencesKeywordList):
        mathPhysicalSciencesMajorList.append(major)
    else:
        humanitiesMajorList.append(major)

# The final list of "Fine Arts"-based majors
print('Fine Arts Majors:')
for major in fineArtsMajorList:
    print(major[0])
print('------------------------')

# The final list of "Social Sciencs"-based majors
print('Social Sciences Majors:')
for major in socialSciencesMajorList:
    print(major[0])
print('------------------------')


# The final list of "Physical Sciences"-based majors
print('Physical Sciences Majors:')
for major in mathPhysicalSciencesMajorList:
    print(major[0])

print('------------------------')

# The final list of "Humanities"-based majors
print('Humanties Majors:')
for major in humanitiesMajorList:
    print(major[0])
    
print('------------------------')


# Exporting all of the major groups
getAllRequirements(fineArtsMajorList,'fareqs.csv')
getAllRequirements(socialSciencesMajorList,'ssreqs.csv')
getAllRequirements(mathPhysicalSciencesMajorList,'mpreqs.csv')
getAllRequirements(humanitiesMajorList,'hmreqs.csv')
# Out:
# Fine Arts Majors:
# Art History Major
# Art Studio Major
# Cinema and Digital Media Major
# Music Major
# Theatre and Dance Major
# Undeclared—Fine Arts
# ------------------------
# Social Sciences Majors:
# Anthropology Major
# Economics Major
# International Relations Major
# Political Science Major
# Political Science – Public Service  Major
# Psychology Major
# Sociology Major
# Sociology – Organizational Studies Major
# Undeclared—Social Sciences
# ------------------------
# Physical Sciences Majors:
# Applied Mathematics Major
# Applied Physics Major
# Chemical Physics Major
# Chemistry Major
# Computer Science Major
# Geology Major
# Marine and Coastal Science—Oceans and the Earth System
# Mathematical Analytics and Operations Research Major
# Mathematical and Scientific Computation Major
# Mathematics Major
# Pharmaceutical Chemistry Major
# Physics Major
# Science and Technology Studies Major
# Statistics Major
# Undeclared—Physical Sciences
# ------------------------
# Humanties Majors:
# African American and African Studies Major
# American Studies Major
# Asian American Studies Major
# Chicana/Chicano Studies Major
# Chinese Major
# Classical Civilization Major
# Cognitive Science Major
# Communication Major
# Comparative Literature Major
# Design Major
# East Asian Studies Major
# English Major
# French Major
# Gender, Sexuality and Women's Studies Major
# German Major
# History Major
# Italian Major
# Japanese Major
# Linguistics Major
# Medieval and Early Modern Studies Major
# Middle East/South Asia Studies Major
# Native American Studies Major
# Philosophy Major
# Religious Studies Major
# Russian Major
# Spanish Major
# Undeclared—Humanities
# ------------------------
# Art History Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/AHI/AHIreqt.html
# ['Art History 1A', 'Art History 1B', 'Art History 1C', 'Art History 1D', 'Art History 1DV', 'Art History 1E', 'Art History 5', 'Art History 25', 'Any lower division Art Studio course except Art 10', 'Any lower division Art Studio course except Art 30']
# ------------------
# Art Studio Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ART/ARTreqt.html
# ['Art Studio 2', 'Art Studio 5', 'Art Studio 7', 'Art Studio 8', 'Art Studio 9', 'Art Studio 11', 'Art Studio 12', 'Art Studio 24', 'Art Studio 30', 'Art History 1A', 'Art History 1B', 'Art History 1C', 'Art History 1D', 'Art History 1DV', 'Art History 1E', 'Art History 5', 'Art History 10', 'Art History 25']
# ------------------
# Cinema and Digital Media Major
# http://catalog.ucdavis.edu/programs/CTS/CTSreqt.html
# ['Film Studies 1', 'Technocultural Studies 1', 'Technocultural Studies 5', 'Cinema and Technocultural Studies 12', 'Cinema and Technocultural Studies 20', 'Cinema and Technocultural Studies 40A', 'Cinema and Technocultural Studies 40B', 'Cinema and Technocultural Studies 41A', 'Cinema and Technocultural Studies 41B', 'Film Studies 45']
# ------------------
# Music Major
# http://catalog.ucdavis.edu/Programs/MUS/MUSreqt.html
# ['Music 6A', 'Music 6B', 'Music 6C', 'Plus Music 2A', 'Plus Music 2B', 'Plus Music 2C', 'And Music 16A', 'And Music 16B', 'And Music 16C', 'Music 7A', 'Music 7B', 'Music 7C', 'Plus Music 17A', 'Plus Music 17B', 'Plus Music 17C', 'Music 24A', 'Music 24B', 'Music 24C']
# ------------------
# Theatre and Dance Major
# http://catalog.ucdavis.edu/programs/DRA/DRAreqt.html
# ['Dramatic Art 28', 'Dramatic Art 55', 'Dramatic Art 56A', 'Dramatic Art 56B', 'Dramatic Art 56C']
# ------------------
# Anthropology Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ANT/ANTreqt.html
# ['Anthropology 1', 'Anthropology 2', 'Anthropology 3', 'Anthropology 15', 'Anthropology 23', 'Anthropology 24', 'Anthropology 25', 'Anthropology 28', 'Anthropology 50', 'Anthropology 54', 'Anthropology 13', 'Sociology 46B', 'Statistics 13', 'Statistics 32']
# ------------------
# Economics Major
# http://catalog.ucdavis.edu/programs/ECN/ECNreqt.html
# ['Economics 1A', 'Economics 1B', 'Statistics 13', 'Statistics 32', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 21A', 'Mathematics 21B']
# ------------------
# International Relations Major
# http://catalog.ucdavis.edu/Programs/POL/POLreqt.html#IRE
# ['Political Science 51', 'Statistics 13', 'Statistics 32']
# ------------------
# Political Science Major
# http://catalog.ucdavis.edu/Programs/POL/POLreqt.html#Political
# ['Political Science 51', 'Statistics 13', 'Statistics 32']
# ------------------
# Political Science – Public Service  Major
# http://catalog.ucdavis.edu/Programs/POL/POLreqt.html#Public
# ['Political Science 51', 'Statistics 13', 'Statistics 32']
# ------------------
# Psychology Major
# http://catalog.ucdavis.edu/Programs/PSC/PSCreqt.html
# ['Psychology 1', 'Psychology 41', 'Statistics 13', 'Strongly recommended that Psychology 41', 'Statistics 13', 'Biological Sciences 2A', 'Biological Sciences 10', 'Anthropology 1', 'Molecular and Cellular Biology 10', 'Neurobiology, Physiology, and Behavior 10']
# ------------------
# Sociology Major
# http://catalog.ucdavis.edu/Programs/SOC/SOCreqt.html
# ['Sociology 1', 'Sociology 46A', 'Sociology 46B', 'Sociology 2', 'Sociology 3', 'Sociology 4', 'Sociology 5', 'Sociology 11', 'Sociology 25', 'Sociology 30A', 'Sociology 30B', 'Anthropology 2', 'Anthropology 20', 'Select from History 4A', 'Select from History 4B', 'Select from History 4C', 'Select from History 6', 'Select from History 7A', 'Select from History 7B', 'Select from History 7C', 'Select from History 8', 'Select from History 9A', 'Select from History 9B', 'Select from History 10C', 'Select from History 15', 'Select from History 17A', 'Select from History 17B', 'Select from Philosophy 5', 'Select from Philosophy 14', 'Select from Philosophy 24']
# ------------------
# Sociology – Organizational Studies Major
# http://catalog.ucdavis.edu/Programs/SOC/SOCreqt.html#Org
# ['Sociology 1', 'Sociology 46A', 'Sociology 46B', 'Sociology 2', 'Sociology 3', 'Sociology 4', 'Sociology 5', 'Sociology 11', 'Sociology 25', 'Sociology 30A', 'Sociology 30B', 'Anthropology 2', 'Anthropology 20', 'Select from History 4A', 'Select from History 4B', 'Select from History 4C', 'Select from History 6', 'Select from History 7A', 'Select from History 7B', 'Select from History 7C', 'Select from History 8', 'Select from History 9A', 'Select from History 9B', 'Select from History 10C', 'Select from History 15', 'Select from History 17A', 'Select from History 17B', 'Select from Philosophy 5', 'Select from Philosophy 14', 'Select from Philosophy 24']
# ------------------
# Applied Mathematics Major
# http://registrar.ucdavis.edu/UCDWebCatalog/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Applied Physics Major
# http://registrar.ucdavis.edu/UCDWebCatalog/Programs/PHY/PHYreqt.html
# ['Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Physics 9HA', 'Physics 9HB', 'Physics 9HC', 'Physics 9HD', 'Physics 9HE', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B']
# ------------------
# Chemical Physics Major
# http://catalog.ucdavis.edu/programs/CHE/CHEreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C']
# ------------------
# Chemistry Major
# http://catalog.ucdavis.edu/programs/CHE/CHEreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C']
# ------------------
# Computer Science Major
# http://catalog.ucdavis.edu/programs/compsci/compscireqt.html
# ['Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 22A', 'Mathematics 67', 'Computer Science Engineering 20', 'Computer Science Engineering 30', 'Computer Science Engineering 40', 'Computer Science Engineering 60', 'Computer Science Engineering 50', 'Electrical and Computer Engineering 70', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2A', 'Chemistry 2B', 'Biological Sciences 2A', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 21D']
# ------------------
# Geology Major
# http://catalog.ucdavis.edu/programs/EPS/EPSreqt.html
# ['Geology 3', 'Geology 3L', 'Geology 50', 'Geology 50L', 'Geology 60', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 21A', 'Mathematics 21B', 'Chemistry 2A', 'Chemistry 2B', 'Physics 7A', 'Physics 7B', 'Statistics 13', 'Statistics 13V', 'Statistics 32']
# ------------------
# Marine and Coastal Science—Oceans and the Earth System
# http://catalog.ucdavis.edu/programs/MCS/MCSreqt.html
# ['Biological Sciences 2A', 'Biological Sciences 2B', 'Biological Sciences 2C', 'Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Chemistry 8A', 'Chemistry 8B', 'Evolution & Ecology 12', 'Geology 16']
# ------------------
# Mathematical Analytics and Operations Research Major
# http://catalog.ucdavis.edu/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Mathematical and Scientific Computation Major
# http://catalog.ucdavis.edu/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Mathematics Major
# http://catalog.ucdavis.edu/Programs/MAT/MATreqt.html
# ['Mathematics 12', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22B', 'Mathematics 25', 'Mathematics 22A', 'Mathematics 67', 'Computer Science 30', 'Engineering 6', 'Mathematics 22AL', 'Basic knowledge of MATLAB is required for both Mathematics 67', 'Basic knowledge of MATLAB is required for both Mathematics 22A.']
# ------------------
# Pharmaceutical Chemistry Major
# http://catalog.ucdavis.edu/programs/CHE/CHEreqt.html
# ['Chemistry 2A', 'Chemistry 2B', 'Chemistry 2C', 'Chemistry 2AH', 'Chemistry 2BH', 'Chemistry 2CH', 'Physics 7A', 'Physics 7B', 'Physics 7C', 'Physics 9A', 'Physics 9B', 'Physics 9C', 'Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C']
# ------------------
# Physics Major
# http://catalog.ucdavis.edu/Programs/PHY/PHYreqt.html
# ['Physics 9A', 'Physics 9B', 'Physics 9C', 'Physics 9D', 'Physics 9HA', 'Physics 9HB', 'Physics 9HC', 'Physics 9HD', 'Physics 9HE', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 21D', 'Mathematics 22A', 'Mathematics 22B']
# ------------------
# Science and Technology Studies Major
# http://catalog.ucdavis.edu/programs/STS/STSreqt.html
# ['Science and Technology Studies 1', 'Science and Technology Studies 20', 'Eight units selected from American Studies 1A', 'Eight units selected from American Studies 1E', 'Eight units selected from American Studies 5', 'Environmental Studies 1', 'Humanities 3', 'Philosophy 30', 'Philosophy 31', 'Philosophy 32', 'Science and Society 1', 'Science and Society 2', 'Science and Society 3', 'Science and Society 5', 'Science and Technology Studies 32']
# ------------------
# Statistics Major
# http://catalog.ucdavis.edu/programs/STA/STAreqt.html
# ['Mathematics 16A', 'Mathematics 16B', 'Mathematics 16C', 'Mathematics 17A', 'Mathematics 17B', 'Mathematics 17C', 'Mathematics 21A', 'Mathematics 21B', 'Mathematics 21C', 'Mathematics 22A', 'Computer Science Engineering 30', 'Computer Science Engineering 40', 'Statistics 32']
# ------------------
# African American and African Studies Major
# http://catalog.ucdavis.edu/programs/AAS/AASreqt.html
# ['African American and African Studies 10', 'African American and African Studies 12', 'African American and African Studies 15', 'African American and African Studies 17', 'African American and African Studies 18', 'African American and African Studies 50', 'African American and African Studies 51', 'African American and African Studies 52', 'African American and African Studies 80', 'Anthropology 2', 'Economics 1A', 'Economics 1B', 'Geography 2', 'Sociology 1', 'Political Science 1', 'Political Science 2', 'Psychology 1', 'Chicana/o Studies 10', 'Native American Studies 1', 'Native American Studies 10', 'Women & Gender Studies 50', 'American Studies 10', 'Asian American Studies 1', 'Asian American Studies 2', 'History 15', 'History 17A', 'History 17B', 'African American and African Studies 16', 'African American and African Studies 51', 'African American and African Studies 54', 'Dramatic Art 41A', 'Dramatic Art 41B', 'Dramatic Art 44A', 'Dramatic Art 44B', 'Music 28']
# ------------------
# American Studies Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/AMS/AMSreqt.html
# ['American Studies 10', 'African American and African Studies 10', 'Asian American Studies 1', 'Chicana/o Studies 10', 'Native American Studies 1', 'Anthropology 2', 'Sociology 2', 'Women\x92s Studies 50', 'History 17A', 'History 17B', 'History 72A', 'History 72B', 'English 30A', 'English 30B', 'Film Studies 1']
# ------------------
# Asian American Studies Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/ASA/ASAreqt.html
# ['Asian American Studies 1', 'Asian American Studies 2', 'Asian American Studies 3', 'Asian American Studies 4', 'lower division courses of at least 4', 'lower division courses of at least units are acceptable except those numbered 92', 'lower division courses of at least units are acceptable except those numbered 97T', 'lower division courses of at least units are acceptable except those numbered 98', 'lower division courses of at least units are acceptable except those numbered 99)', 'Anthropology 13', 'Art History 5', 'Art Studio 10', 'Art Studio 30', 'Chicana/o Studies 23', 'English 42', 'Native American Studies 46', 'Philosophy 5', 'Political Science 51', 'Psychology 41', 'Sociology 46A', 'Sociology 46B', 'Statistics 13']
# ------------------
# Chicana/Chicano Studies Major
# http://registrar.ucdavis.edu/UCDWebCatalog/programs/CHI/CHIreqt.html
# ['Chicana/o Studies 10', 'Chicana/o Studies 50', 'Chicana/o Studies 21', 'Chicana/o Studies 40', 'One of Chicana/o Studies 60', 'One of Chicana/o Studies 65', 'One of Chicana/o Studies 70', 'One of Chicana/o Studies 73', 'Spanish 1', 'Spanish 2', 'Spanish 3', 'Spanish 28', 'Spanish 31', 'Spanish 32']
# ------------------
# Chinese Major
# http://catalog.ucdavis.edu/programs/EAC/EACreqt.html#Chinese
# ['Chinese 1', 'Chinese 2', 'Chinese 3', 'Chinese 4', 'Chinese 5', 'Chinese 6', 'OR 1BL', 'OR 2BL', 'OR 3BL', 'OR 1CN', 'OR 2CN', 'OR 3CN', 'Chinese 10', 'Chinese 11', 'Chinese 50', 'Comparative Literature 14', 'Japanese 10', 'Linguistics 1', 'History 9A.']
# ------------------
# Classical Civilization Major
# http://catalog.ucdavis.edu/programs/CLA/CLAcourses.html
# []
# ------------------
# Cognitive Science Major
# http://cogsci.ucdavis.edu/program.html
# []
# ------------------
# Communication Major
# http://catalog.ucdavis.edu/programs/CMN/CMNreqt.html
# ['Anthropology 4', 'Linguistics 1', 'Communication 10Y', 'Communication 1', 'Communication 3', 'Communication 5/Linguistics', 'Communication 5', 'Computer Science 15', 'Philosophy 12', 'Psychology 1', 'Sociology 1', 'Statistics 13', 'Sociology 46B']
# ------------------
# Comparative Literature Major
# http://catalog.ucdavis.edu/programs/COM/COMreqt.html
# ['Comparative Literature 1', 'Comparative Literature 2', 'Comparative Literature 3', 'Comparative Literature 4', 'from excluding the 10', 'It is recommended that students who do not use a European language toward the major take one of the remaining required lower division courses in the 53', 'It is recommended that students who do not use a European language toward the major take one of the remaining required lower division courses in the series, preferably the 53']
# ------------------
# Design Major
# http://catalog.ucdavis.edu/programs/DES/DESreqt.html
# ['Design 1', 'Art 2', 'Design 14', 'Design 15', 'Design 16', 'University Writing Program 11', 'University Writing Program 18', 'University Writing Program 19', 'Design 40A', 'Design 40B', 'Design 40C', 'Design 21', 'Design 31', 'Design 37', 'Design 50', 'Design 60', 'Design 70', 'Design 77', 'Art 9']
# ------------------
# East Asian Studies Major
# http://catalog.ucdavis.edu/programs/EAS/EASreqt.html
# ['History 9A', 'History 9B', 'Art History 1D', 'Chinese 7', 'Chinese 10', 'Chinese 11', 'Comparative Literature 53A', 'East Asian Studies 88', 'Japanese 10', 'Japanese 25', 'Japanese 50', 'Religious Studies, 75']
# ------------------
# English Major
# http://catalog.ucdavis.edu/programs/ENL/ENLreqt.html
# ['English 3', 'University Writing Program 1', 'English 40', 'English 43', 'English 44', 'English 45', 'English 10A', 'English 10B', 'English 10C']
# ------------------
# French Major
# http://registrar.ucdavis.edu/UCDWebCatalog/Programs/FRE/FREreqt.html
# ['French 1', 'French 2', 'French 3', 'French 21', 'French 22', 'French 23', 'Linguistics 1', 'Linguistics 4']
# ------------------
# Gender, Sexuality and Women's Studies Major
# http://catalog.ucdavis.edu/programs/WMS/WMSreqt.html
# ['Women\x92s Studies, 50', 'Women\x92s Studies, 60', 'Women\x92s Studies, 70', 'African American and African Studies 10', 'African American and African Studies 17', 'American Studies 21', 'American Studies 30', 'Anthropology 2', 'Anthropology 20', 'Anthropology 30', 'Asian American Studies 1', 'Asian American Studies 2', 'Chicana/o Studies 10', 'Chicana/o Studies 21S', 'Chicana/o Studies 50', 'Comparative Literature 12', 'Dramatic Art 1', 'English 3', 'History 72A', 'History 72B', 'History 85', 'Native American Studies 10', 'Native American Studies 32', 'Political Science 7', 'Psychology 1', 'Science and Technology 12', 'Science and Technology 20', 'Science and Technology 32', 'Sociology 2', 'Sociology 3', 'Sociology 11', 'Sociology 30A', 'Sociology 30B', 'Textiles and Clothing 7', 'Undergraduate Writing Program 19', 'Women\x92s Studies 20', 'Women\x92s Studies 80']
# ------------------
# German Major
# http://catalog.ucdavis.edu/Programs/GER/GERreqt.html
# ['German 20', 'German 21', 'German 22']
# ------------------
# History Major
# http://catalog.ucdavis.edu/Programs/HIS/HISreqt.html
# []
# ------------------
# Italian Major
# http://catalog.ucdavis.edu/Programs/ITA/ITAreqt.html
# ['Italian 1', 'Italian 2', 'Italian 3', 'Italian 4', 'Italian 5', 'Italian 9']
# ------------------
# Japanese Major
# http://catalog.ucdavis.edu/Programs/EAC/EACreqt.html
# ['Chinese 1', 'Chinese 2', 'Chinese 3', 'Chinese 4', 'Chinese 5', 'Chinese 6', 'OR 1BL', 'OR 2BL', 'OR 3BL', 'OR 1CN', 'OR 2CN', 'OR 3CN', 'Chinese 10', 'Chinese 11', 'Chinese 50', 'Comparative Literature 14', 'Japanese 10', 'Linguistics 1', 'History 9A.']
# ------------------
# Linguistics Major
# http://catalog.ucdavis.edu/Programs/LIN/LINreqt.html
# ['Linguistics 1']
# ------------------
# Medieval and Early Modern Studies Major
# http://catalog.ucdavis.edu/Programs/MST/MSTreqt.html
# ['Medieval Studies 20A', 'Medieval Studies 20B', 'Art History 1B', 'Art History 1C', 'Art History 1E', 'Comparative Literature 2', 'Comparative Literature 10A', 'Comparative Literature 10B', 'Comparative Literature 10C', 'Comparative Literature 10D', 'Comparative Literature 10E', 'English 10A', 'German 48', 'History 4A', 'History 4B', 'Humanities 1*', 'Humanities 9', 'Philosophy 21', 'Philosophy 22']
# ------------------
# Middle East/South Asia Studies Major
# http://catalog.ucdavis.edu/programs/MSA/MSAreqt.html
# ['History 6', 'History 8', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 1', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 2', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 3', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 21', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 22', 'Middle East/South Asia Studies regional languages accepted with petition). Arabic 23', 'Hebrew 1', 'Hebrew 2', 'Hebrew 3', 'Hebrew 21', 'Hebrew 22', 'Hebrew 23', 'Hindi/Urdu 1', 'Hindi/Urdu 2', 'Hindi/Urdu 3', 'Hindi/Urdu 21', 'Hindi/Urdu 22', 'Hindi/Urdu 23']
# ------------------
# Native American Studies Major
# http://catalog.ucdavis.edu/Programs/NAS/NASreqt.html
# ['Native American Studies 1', 'Native American Studies 10', 'Native American Studies 12', 'Native American Studies 5', 'Native American Studies 12', 'Native American Studies 32', 'Native American Studies 33', 'Native American Studies 34', 'African American and African Studies 12', 'African American and African Studies 52', 'Anthropology 2', 'Anthropology 20', 'Anthropology 24', 'Asian American Studies 1', 'Asian American Studies 2', 'Asian American Studies 4', 'Chicana/o Studies 10', 'Chicana/o Studies 21', 'Chicana/o Studies 23', 'Comparative Literature 25', 'Community and Regional Development 2', 'Environmental Science and Policy 10', 'History 7A', 'History 7B', 'History 7C', 'History 17A', 'Linguistics 1', 'Religious Studies 90', 'Technocultural Studies 2']
# ------------------
# Philosophy Major
# http://catalog.ucdavis.edu/Programs/PHI/PHIreqt.html
# ['Philosophy 1', 'Philosophy 21', 'Philosophy 22', 'Philosophy 13G', 'Philosophy 14', 'Philosophy 15', 'Philosophy 24', 'Philosophy 30', 'Philosophy 31', 'Philosophy 32', 'Philosophy 38', 'Philosophy 17', 'Philosophy 12']
# ------------------
# Religious Studies Major
# http://catalog.ucdavis.edu/Programs/RST/RSTreqt.html
# ['One course from the Religious Studies 1']
# ------------------
# Russian Major
# http://catalog.ucdavis.edu/Programs/RUS/RUSreqt.html
# []
# ------------------
# Spanish Major
# http://catalog.ucdavis.edu/programs/SPA/SPAreqt.html
# ['Spanish 1', 'Spanish 2', 'Spanish 3', 'Spanish 21', 'Spanish 21S', 'Spanish 22', 'Spanish 22S', 'Spanish 23', 'Spanish 23S', 'Spanish 24', 'Spanish 24S', 'Spanish 31', 'Spanish 32', 'Spanish 33', 'Linguistics 1']
# ------------------
# [['African American and African Studies 10',
#   'African American and African Studies 12',
#   'African American and African Studies 15',
#   'African American and African Studies 17',
#   'African American and African Studies 18',
#   'African American and African Studies 50',
#   'African American and African Studies 51',
#   'African American and African Studies 52',
#   'African American and African Studies 80',
#   'Anthropology 2',
#   'Economics 1A',
#   'Economics 1B',
#   'Geography 2',
#   'Sociology 1',
#   'Political Science 1',
#   'Political Science 2',
#   'Psychology 1',
#   'Chicana/o Studies 10',
#   'Native American Studies 1',
#   'Native American Studies 10',
#   'Women & Gender Studies 50',
#   'American Studies 10',
#   'Asian American Studies 1',
#   'Asian American Studies 2',
#   'History 15',
#   'History 17A',
#   'History 17B',
#   'African American and African Studies 16',
#   'African American and African Studies 51',
#   'African American and African Studies 54',
#   'Dramatic Art 41A',
#   'Dramatic Art 41B',
#   'Dramatic Art 44A',
#   'Dramatic Art 44B',
#   'Music 28'],
#  ['American Studies 10',
#   'African American and African Studies 10',
#   'Asian American Studies 1',
#   'Chicana/o Studies 10',
#   'Native American Studies 1',
#   'Anthropology 2',
#   'Sociology 2',
#   'Women\x92s Studies 50',
#   'History 17A',
#   'History 17B',
#   'History 72A',
#   'History 72B',
#   'English 30A',
#   'English 30B',
#   'Film Studies 1'],
#  ['Asian American Studies 1',
#   'Asian American Studies 2',
#   'Asian American Studies 3',
#   'Asian American Studies 4',
#   'lower division courses of at least 4',
#   'lower division courses of at least units are acceptable except those numbered 92',
#   'lower division courses of at least units are acceptable except those numbered 97T',
#   'lower division courses of at least units are acceptable except those numbered 98',
#   'lower division courses of at least units are acceptable except those numbered 99)',
#   'Anthropology 13',
#   'Art History 5',
#   'Art Studio 10',
#   'Art Studio 30',
#   'Chicana/o Studies 23',
#   'English 42',
#   'Native American Studies 46',
#   'Philosophy 5',
#   'Political Science 51',
#   'Psychology 41',
#   'Sociology 46A',
#   'Sociology 46B',
#   'Statistics 13'],
#  ['Chicana/o Studies 10',
#   'Chicana/o Studies 50',
#   'Chicana/o Studies 21',
#   'Chicana/o Studies 40',
#   'One of Chicana/o Studies 60',
#   'One of Chicana/o Studies 65',
#   'One of Chicana/o Studies 70',
#   'One of Chicana/o Studies 73',
#   'Spanish 1',
#   'Spanish 2',
#   'Spanish 3',
#   'Spanish 28',
#   'Spanish 31',
#   'Spanish 32'],
#  ['Chinese 1',
#   'Chinese 2',
#   'Chinese 3',
#   'Chinese 4',
#   'Chinese 5',
#   'Chinese 6',
#   'OR 1BL',
#   'OR 2BL',
#   'OR 3BL',
#   'OR 1CN',
#   'OR 2CN',
#   'OR 3CN',
#   'Chinese 10',
#   'Chinese 11',
#   'Chinese 50',
#   'Comparative Literature 14',
#   'Japanese 10',
#   'Linguistics 1',
#   'History 9A.'],
#  [],
#  [],
#  ['Anthropology 4',
#   'Linguistics 1',
#   'Communication 10Y',
#   'Communication 1',
#   'Communication 3',
#   'Communication 5/Linguistics',
#   'Communication 5',
#   'Computer Science 15',
#   'Philosophy 12',
#   'Psychology 1',
#   'Sociology 1',
#   'Statistics 13',
#   'Sociology 46B'],
#  ['Comparative Literature 1',
#   'Comparative Literature 2',
#   'Comparative Literature 3',
#   'Comparative Literature 4',
#   'from excluding the 10',
#   'It is recommended that students who do not use a European language toward the major take one of the remaining required lower division courses in the 53',
#   'It is recommended that students who do not use a European language toward the major take one of the remaining required lower division courses in the series, preferably the 53'],
#  ['Design 1',
#   'Art 2',
#   'Design 14',
#   'Design 15',
#   'Design 16',
#   'University Writing Program 11',
#   'University Writing Program 18',
#   'University Writing Program 19',
#   'Design 40A',
#   'Design 40B',
#   'Design 40C',
#   'Design 21',
#   'Design 31',
#   'Design 37',
#   'Design 50',
#   'Design 60',
#   'Design 70',
#   'Design 77',
#   'Art 9'],
#  ['History 9A',
#   'History 9B',
#   'Art History 1D',
#   'Chinese 7',
#   'Chinese 10',
#   'Chinese 11',
#   'Comparative Literature 53A',
#   'East Asian Studies 88',
#   'Japanese 10',
#   'Japanese 25',
#   'Japanese 50',
#   'Religious Studies, 75'],
#  ['English 3',
#   'University Writing Program 1',
#   'English 40',
#   'English 43',
#   'English 44',
#   'English 45',
#   'English 10A',
#   'English 10B',
#   'English 10C'],
#  ['French 1',
#   'French 2',
#   'French 3',
#   'French 21',
#   'French 22',
#   'French 23',
#   'Linguistics 1',
#   'Linguistics 4'],
#  ['Women\x92s Studies, 50',
#   'Women\x92s Studies, 60',
#   'Women\x92s Studies, 70',
#   'African American and African Studies 10',
#   'African American and African Studies 17',
#   'American Studies 21',
#   'American Studies 30',
#   'Anthropology 2',
#   'Anthropology 20',
#   'Anthropology 30',
#   'Asian American Studies 1',
#   'Asian American Studies 2',
#   'Chicana/o Studies 10',
#   'Chicana/o Studies 21S',
#   'Chicana/o Studies 50',
#   'Comparative Literature 12',
#   'Dramatic Art 1',
#   'English 3',
#   'History 72A',
#   'History 72B',
#   'History 85',
#   'Native American Studies 10',
#   'Native American Studies 32',
#   'Political Science 7',
#   'Psychology 1',
#   'Science and Technology 12',
#   'Science and Technology 20',
#   'Science and Technology 32',
#   'Sociology 2',
#   'Sociology 3',
#   'Sociology 11',
#   'Sociology 30A',
#   'Sociology 30B',
#   'Textiles and Clothing 7',
#   'Undergraduate Writing Program 19',
#   'Women\x92s Studies 20',
#   'Women\x92s Studies 80'],
#  ['German 20', 'German 21', 'German 22'],
#  [],
#  ['Italian 1',
#   'Italian 2',
#   'Italian 3',
#   'Italian 4',
#   'Italian 5',
#   'Italian 9'],
#  ['Chinese 1',
#   'Chinese 2',
#   'Chinese 3',
#   'Chinese 4',
#   'Chinese 5',
#   'Chinese 6',
#   'OR 1BL',
#   'OR 2BL',
#   'OR 3BL',
#   'OR 1CN',
#   'OR 2CN',
#   'OR 3CN',
#   'Chinese 10',
#   'Chinese 11',
#   'Chinese 50',
#   'Comparative Literature 14',
#   'Japanese 10',
#   'Linguistics 1',
#   'History 9A.'],
#  ['Linguistics 1'],
#  ['Medieval Studies 20A',
#   'Medieval Studies 20B',
#   'Art History 1B',
#   'Art History 1C',
#   'Art History 1E',
#   'Comparative Literature 2',
#   'Comparative Literature 10A',
#   'Comparative Literature 10B',
#   'Comparative Literature 10C',
#   'Comparative Literature 10D',
#   'Comparative Literature 10E',
#   'English 10A',
#   'German 48',
#   'History 4A',
#   'History 4B',
#   'Humanities 1*',
#   'Humanities 9',
#   'Philosophy 21',
#   'Philosophy 22'],
#  ['History 6',
#   'History 8',
#   'Middle East/South Asia Studies regional languages accepted with petition). Arabic 1',
#   'Middle East/South Asia Studies regional languages accepted with petition). Arabic 2',
#   'Middle East/South Asia Studies regional languages accepted with petition). Arabic 3',
#   'Middle East/South Asia Studies regional languages accepted with petition). Arabic 21',
#   'Middle East/South Asia Studies regional languages accepted with petition). Arabic 22',
#   'Middle East/South Asia Studies regional languages accepted with petition). Arabic 23',
#   'Hebrew 1',
#   'Hebrew 2',
#   'Hebrew 3',
#   'Hebrew 21',
#   'Hebrew 22',
#   'Hebrew 23',
#   'Hindi/Urdu 1',
#   'Hindi/Urdu 2',
#   'Hindi/Urdu 3',
#   'Hindi/Urdu 21',
#   'Hindi/Urdu 22',
#   'Hindi/Urdu 23'],
#  ['Native American Studies 1',
#   'Native American Studies 10',
#   'Native American Studies 12',
#   'Native American Studies 5',
#   'Native American Studies 12',
#   'Native American Studies 32',
#   'Native American Studies 33',
#   'Native American Studies 34',
#   'African American and African Studies 12',
#   'African American and African Studies 52',
#   'Anthropology 2',
#   'Anthropology 20',
#   'Anthropology 24',
#   'Asian American Studies 1',
#   'Asian American Studies 2',
#   'Asian American Studies 4',
#   'Chicana/o Studies 10',
#   'Chicana/o Studies 21',
#   'Chicana/o Studies 23',
#   'Comparative Literature 25',
#   'Community and Regional Development 2',
#   'Environmental Science and Policy 10',
#   'History 7A',
#   'History 7B',
#   'History 7C',
#   'History 17A',
#   'Linguistics 1',
#   'Religious Studies 90',
#   'Technocultural Studies 2'],
#  ['Philosophy 1',
#   'Philosophy 21',
#   'Philosophy 22',
#   'Philosophy 13G',
#   'Philosophy 14',
#   'Philosophy 15',
#   'Philosophy 24',
#   'Philosophy 30',
#   'Philosophy 31',
#   'Philosophy 32',
#   'Philosophy 38',
#   'Philosophy 17',
#   'Philosophy 12'],
#  ['One course from the Religious Studies 1'],
#  [],
#  ['Spanish 1',
#   'Spanish 2',
#   'Spanish 3',
#   'Spanish 21',
#   'Spanish 21S',
#   'Spanish 22',
#   'Spanish 22S',
#   'Spanish 23',
#   'Spanish 23S',
#   'Spanish 24',
#   'Spanish 24S',
#   'Spanish 31',
#   'Spanish 32',
#   'Spanish 33',
#   'Linguistics 1']]

# %% [markdown]
# Sources used:
# https://stackoverflow.com/questions/7055048/how-to-extract-certain-parts-of-a-web-page-in-python
# https://stackoverflow.com/questions/10393157/splitting-a-string-with-multiple-delimiters-in-python
# https://stackoverflow.com/questions/1080411/retrieve-links-from-web-page-using-python-and-beautifulsoup
# https://stackoverflow.com/questions/43043437/wordcloud-python-with-generate-from-frequencies
# https://stackoverflow.com/questions/40444821/convert-csv-to-a-string-variable
# https://stackoverflow.com/questions/3271478/check-list-of-words-in-another-string
# https://www.tutorialspoint.com/python/list_remove.htm
# https://pythonspot.com/reading-csv-files-in-python/
# http://amueller.github.io/word_cloud/auto_examples/simple.html#sphx-glr-auto-examples-simple-py
